# %%
def opts():
  opts = {}
  opts['--lr'] = {'default'=1.6, 'type'=float}
  opts['--momentum'] = {'default'=0.9, 'type'=float}
  opts['--lr_decay']={'default'=0.8, 'type'=float}
  opts['--cycle_length']={'default'=10, 'type'=int}
  opts['--multi_factor']={'default'=1.5, 'type'=float}
  opts['--warm_up_epoch']={'default'=5, 'type'=int}
  opts['--optimizer'] = {'default'='SGD', 'type'=str}
  return opts
